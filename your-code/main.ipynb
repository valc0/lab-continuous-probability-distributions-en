# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
uniform.rvs(2, 8, size=10)
# Out:
# array([9.66789806, 3.42044694, 7.80232002, 8.55495464, 7.77908145,
#        3.18257762, 4.64111972, 9.23490838, 6.01179385, 6.70606993])

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
def uniform_generator(bottom, ceiling, count):
    scale = ceiling - bottom
    return uniform.rvs(loc=bottom, scale=scale, size=count)

uniform_generator
# Out:
# <function __main__.uniform_generator(bottom, ceiling, count)>

# %%
uni_data1 = uniform_generator(bottom=10, ceiling=15, count=100)
uni_data2 = uniform_generator(bottom=10, ceiling=60, count=1000)

print(f'fun1: {uni_data1}')
print(f'fun2: {uni_data2}')
# Out:
# fun1: [11.88554378 11.13351473 14.44676544 14.72571823 10.87240003 13.8136627
#  14.53403559 11.73284011 14.44944375 12.79279006 13.3254425  10.40177638
#  14.56436912 11.26743801 11.47595622 12.56239457 14.29603037 10.30953896
#  14.67279199 13.63667609 12.81955995 13.78906359 11.16403522 14.47034287
#  12.07112007 13.89387088 14.57830951 13.41154936 10.97098444 13.23533191
#  10.53190499 14.64272499 11.55735322 13.95415431 12.53413382 12.59561006
#  10.48200602 13.61085907 13.97909238 10.60938248 13.54375943 13.75466767
#  13.32015249 12.42287042 13.57289409 10.59158083 10.1033016  10.07217147
#  14.81251969 12.7248251  11.18912547 13.82461682 12.17528159 11.75490394
#  10.99354792 13.33045415 10.31168434 11.88052989 13.36519667 13.65564751
#  10.40388112 11.40310108 13.15999686 10.20241353 13.46947265 14.62558823
#  14.74923511 11.72657197 12.65297905 10.78191307 10.5939449  13.66405202
#  14.62740547 13.25615835 13.40643383 14.4693829  12.52741413 10.08516032
# ...

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,9), sharey=True)

sns.histplot(
    data = uni_data1,
    bins = 10,
    ax = ax1,
    color = "#439D60",
    edgecolor = ("#00000000")
)

sns.histplot(
    data = uni_data2,
    bins = 10,
    color = "#B74E4E",
    edgecolor = ("#00000000")
)

plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# The second graph has ten times the data point over a much wider range.

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
def normal_generator(mean, std_dev, count):
    return norm.rvs(loc=mean, scale=std_dev, size=count)

# %%
norm_data1 = normal_generator(mean=10, std_dev=1, count=1000)
norm_data2 = normal_generator(mean=10, std_dev=50, count=1000)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,9), sharey=True)

sns.histplot(
    data = norm_data1,
    bins = 50,
    ax = ax1,
    color = "#439D60",
    edgecolor = ("#00000000")
)

sns.histplot(
    data = norm_data2,
    bins = 50,
    color = "#B74E4E",
    edgecolor = ("#00000000")
)

plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [raw]
# # The scale of values is huge in the second graph because the standard deviation is 50 times higher than in the first graph.

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %%
df = pd.read_csv('vehicles.csv')
df = df.copy()

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
plt.figure(figsize=(16,9))

sns.histplot(
    data = df,
    x = 'Fuel Barrels/Year',
    kde = True,
    color = "#539890",
    edgecolor = ("#00000000")
)

plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
plt.figure(figsize=(16,9))

sns.histplot(
    data = df,
    x = 'CO2 Emission Grams/Mile',
    kde = True,
    color = "#539890",
    edgecolor = ("#00000000")
)

plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
plt.figure(figsize=(16,9))

sns.histplot(
    data = df,
    x = 'Combined MPG',
    kde = True,
    color = "#539890",
    edgecolor = ("#00000000")
)

plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# None of them are normally distributed as all have a right skew.

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 10 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
def exponential_generator(mean, count):
    return np.random.exponential(scale=mean, size=count)

# %%
exp_data1 = exponential_generator(mean=1, count=1000)
exp_data2 = exponential_generator(mean=100, count=1000)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,9), sharey=True)

sns.histplot(
    data = exp_data1,
    bins = 100,
    ax = ax1,
    color = "#439D60",
    edgecolor = ("#00000000")
)

sns.histplot(
    data = exp_data2,
    bins = 100,
    color = "#B74E4E",
    edgecolor = ("#00000000")
)

plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# While both graphs look similar, the second one streches much wider because of the higher mean value.

# %% [markdown]
# The mean changes, so the distribution changes as well.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
def exp_prob_less(x, mean=10):
    return 1 - math.exp(-x / mean)

# %%
prob_less = exp_prob_less(15)

print(f'P(x<15) =: {prob_less}')
# Out:
# P(x<15) =: 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
def exp_prob_more(x, mean=10):
    return math.exp(-x / mean)

# %%
prob_more = exp_prob_more(15)

print(f'P(x>15) = {prob_more}')
# Out:
# P(x>15) = 0.22313016014842982
